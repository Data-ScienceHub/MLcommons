# %% [markdown]
# # Import Libraries

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import matplotlib.dates as mdates
import datetime

# %% [markdown]
# # Morris Results

# %%
# Import data
ages = ['UNDER5', 'AGE517', 'AGE1829', 'AGE4049', 'AGE3039', 'AGE5064', 'AGE6574', 'AGE75PLUS']
morris = 'figures_morris'

data = []
for i in range(len(ages)):
    x = pd.read_csv('./results/' + ages[i] + '/' + morris + '/Morris.csv')
    data.append(x)
     
age_total = []
# Age 
for i in range(len(ages)):
    age_total.append(data[i][data[i].Feature == ages[i]])

# Function for formatter
class OOMFormatter(mpl.ticker.ScalarFormatter):
    def __init__(self, order=0, fformat="%1.1f", offset=True, mathText=True):
        self.oom = order
        self.fformat = fformat
        mpl.ticker.ScalarFormatter.__init__(self,useOffset=offset,useMathText=mathText)
    def _set_order_of_magnitude(self):
        self.orderOfMagnitude = self.oom
    def _set_format(self, vmin=None, vmax=None):
        self.format = self.fformat
        if self._useMathText:
            self.format = r'$\mathdefault{%s}$' % self.format

# %% [markdown]
# ## Plot

# %%
# Plot
mpl.rcParams['figure.dpi'] = 1000
fig, ax = plt.subplots(nrows=1, ncols=1, facecolor='w', sharey=True, figsize=(6, 3))
label = ['0-4', '5-17', '18-29', '30-39', '40-49', '50-64', '65-74', '75+']
color = ['gray', '#fde725', '#7ad151', '#22a884', '#2a788e', '#414487', '#440154', 'black']

# plot the same data on both axes
for i in range(len(ages)):
    plt.plot(age_total[i].Delta, age_total[i].Morris_sensitivity, '-', linewidth=1.5, label=label[i], color=color[i])
    
# Scale axes
ax.yaxis.set_major_formatter(OOMFormatter(-4, "%1.2f"))
ax.ticklabel_format(axis='y', style='sci', scilimits=(-4,-4))   
ax.xaxis.set_major_formatter(OOMFormatter(-4, "%1.0f"))
ax.ticklabel_format(axis='x', style='sci', scilimits=(-4,-4))
ax.xaxis.get_offset_text().set_visible(True)

# Format plot
ax.set_xticks([-0.01 , -0.008, -0.006, -0.004,
               -0.002, 0, 0.002, 0.004, 0.006,
               0.008, 0.01 ])
ax.set_xlim(-0.01, 0.01)
ax.set_ylim(-0.085e-4, 0.06e-4)

# Minor ticks
ax.set_xticks([-90e-4, -70e-4, -50e-4, -30e-4, -10e-4, 10e-4, 30e-4, 50e-4, 70e-4, 90e-4], minor=True)
ax.set_yticks([-0.08e-4, -0.06e-4, -0.04e-4, -0.02e-4, 0, 0.02e-4, 0.04e-4, 0.06e-4], minor=False)
ax.set_yticks([-0.07e-4, -0.05e-4, -0.03e-4, -0.01e-4, 0, 0.01e-4, 0.03e-4, 0.05e-4], minor=True)
ax.tick_params(axis='both', which='major', labelsize=12)

# Add labels
plt.ylabel('Scaled Morris Index', size=12)
plt.xlabel('Delta', size=12)
plt.title('Model Sensitivity to Age', size=12)
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left', title='Age Group')
plt.savefig('fig1.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# # Morris Ranking

# %%
# Get delta values
for i in range(0, len(ages)):
    data[i].Delta = round(data[i].Delta, 3)

deltas = list(data[0].Delta.unique())

# Create ranking dataframe
ranking = pd.DataFrame(np.zeros(len(ages)))
ranking = ranking.reindex(index = ['0 - 4 Years','5 - 17 Years','18 - 29 Years', 
                                   '30 - 39 Years', '40 - 49 Years', 
                                   '50 - 64 Years', '65 - 74 Years', '75+ Years'])

# Save values
for j in range(0, 20): 
    one = []
    for i in range(0, len(ages)):
        x = data[i][(data[i]['Delta'] == deltas[j])
                & (data[i]['Feature'] != 'VaccinationFull')]['Morris_sensitivity']
        one.append(x.values[0])
    ranking.insert(j, str(deltas[j]), one, True)
    
ranking = ranking.drop(0, axis=1)

# Show ranking
for i in ranking.columns: 
    ranking[i] = ranking[i].rank(ascending=True)
ranking['mean_rows'] = ranking.mean(axis = 1)
result = ranking[['mean_rows']]

# %%
result.style.background_gradient('Blues', subset=['mean_rows'])\
       .format({'mean_rows': '{:.2f}'})
# Out:
# <style type="text/css">
# #T_6a04c_row0_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_6a04c_row1_col0 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_6a04c_row2_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_6a04c_row3_col0, #T_6a04c_row7_col0 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_6a04c_row4_col0 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_6a04c_row5_col0 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_6a04c_row6_col0 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# </style>
# <table id="T_6a04c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a04c_level0_col0" class="col_heading level0 col0" >mean_rows</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a04c_level0_row0" class="row_heading level0 row0" >0 - 4 Years</th>
#       <td id="T_6a04c_row0_col0" class="data row0 col0" >2.25</td>
#     </tr>
#     <tr>
#       <th id="T_6a04c_level0_row1" class="row_heading level0 row1" >5 - 17 Years</th>
#       <td id="T_6a04c_row1_col0" class="data row1 col0" >2.40</td>
#     </tr>
#     <tr>
#       <th id="T_6a04c_level0_row2" class="row_heading level0 row2" >18 - 29 Years</th>
#       <td id="T_6a04c_row2_col0" class="data row2 col0" >6.80</td>
#     </tr>
#     <tr>
#       <th id="T_6a04c_level0_row3" class="row_heading level0 row3" >30 - 39 Years</th>
#       <td id="T_6a04c_row3_col0" class="data row3 col0" >5.50</td>
#     </tr>
#     <tr>
#       <th id="T_6a04c_level0_row4" class="row_heading level0 row4" >40 - 49 Years</th>
#       <td id="T_6a04c_row4_col0" class="data row4 col0" >5.60</td>
#     </tr>
#     <tr>
#       <th id="T_6a04c_level0_row5" class="row_heading level0 row5" >50 - 64 Years</th>
#       <td id="T_6a04c_row5_col0" class="data row5 col0" >5.30</td>
#     </tr>
#     <tr>
#       <th id="T_6a04c_level0_row6" class="row_heading level0 row6" >65 - 74 Years</th>
#       <td id="T_6a04c_row6_col0" class="data row6 col0" >2.65</td>
#     </tr>
#     <tr>
#       <th id="T_6a04c_level0_row7" class="row_heading level0 row7" >75+ Years</th>
#       <td id="T_6a04c_row7_col0" class="data row7 col0" >5.50</td>
#     </tr>
#   </tbody>
# </table>

# %%
result = result.rename(columns={'mean_rows': 'Morris'}).rank(ascending=True)
result.style.background_gradient('Blues', subset=['Morris'])\
       .format({'Morris': '{:.0f}'})
# Out:
# <style type="text/css">
# #T_7cfa2_row0_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_7cfa2_row1_col0 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_7cfa2_row2_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_7cfa2_row3_col0, #T_7cfa2_row7_col0 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_7cfa2_row4_col0 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_7cfa2_row5_col0 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_7cfa2_row6_col0 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# </style>
# <table id="T_7cfa2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7cfa2_level0_col0" class="col_heading level0 col0" >Morris</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7cfa2_level0_row0" class="row_heading level0 row0" >0 - 4 Years</th>
#       <td id="T_7cfa2_row0_col0" class="data row0 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7cfa2_level0_row1" class="row_heading level0 row1" >5 - 17 Years</th>
#       <td id="T_7cfa2_row1_col0" class="data row1 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_7cfa2_level0_row2" class="row_heading level0 row2" >18 - 29 Years</th>
#       <td id="T_7cfa2_row2_col0" class="data row2 col0" >8</td>
#     </tr>
#     <tr>
#       <th id="T_7cfa2_level0_row3" class="row_heading level0 row3" >30 - 39 Years</th>
#       <td id="T_7cfa2_row3_col0" class="data row3 col0" >6</td>
#     </tr>
#     <tr>
#       <th id="T_7cfa2_level0_row4" class="row_heading level0 row4" >40 - 49 Years</th>
#       <td id="T_7cfa2_row4_col0" class="data row4 col0" >7</td>
#     </tr>
#     <tr>
#       <th id="T_7cfa2_level0_row5" class="row_heading level0 row5" >50 - 64 Years</th>
#       <td id="T_7cfa2_row5_col0" class="data row5 col0" >4</td>
#     </tr>
#     <tr>
#       <th id="T_7cfa2_level0_row6" class="row_heading level0 row6" >65 - 74 Years</th>
#       <td id="T_7cfa2_row6_col0" class="data row6 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_7cfa2_level0_row7" class="row_heading level0 row7" >75+ Years</th>
#       <td id="T_7cfa2_row7_col0" class="data row7 col0" >6</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Ground Truth

# %% [markdown]
# ## Cases by Age
# https://data.cdc.gov/Public-Health-Surveillance/COVID-19-Weekly-Cases-and-Deaths-by-Age-Race-Ethni/hrdz-jaxc

# %% [markdown]
# ### Preprocess

# %%
data = pd.read_csv('Ground Truth/COVID-19_Weekly_Cases_and_Deaths_by_Age__Race_Ethnicity__and_Sex.csv')

# Select all U.S. jurisdictions, age groups, sexes, races/ethnicities
data = data[data.jurisdiction == 'US']
data = data[data.age_group != 'Overall']
data = data[data.sex == 'Overall']
data = data[data.race_ethnicity_combined == 'Overall']
data.drop(columns=[
    'jurisdiction', 'sex', 'race_ethnicity_combined',
    'deaths', 'death_rate_per_100k', 'case_rate_per_100k'
], inplace=True)

# %%
# Convert end_of_week column to DateTime
data['end_of_week'] = pd.to_datetime(data['end_of_week'])
data = data.sort_values(by=['end_of_week', 'age_group'])
data = data.reset_index().drop(columns=['index'])

# %%
# since it is cumulative weekly report, count started from 6 days early
first_date = data['end_of_week'].min() - pd.to_timedelta(6, unit='D')
start_df = pd.DataFrame({'age_group':data['age_group'].unique()})

start_df['end_of_week'] = first_date
start_df['cases'] = 0
data = pd.concat([start_df, data])

# %%
# Select date range (end_of_week = 3/1/2020 to end_of_week = 12/27/2021)
start = max(pd.to_datetime('2020-03-01'), first_date)
end = pd.to_datetime('2021-11-27')
print(f'Whole data contains period {start} to {end}.')

data = data[(data['end_of_week']>=start) & (data['end_of_week']<=end)]
# Out:
# Whole data contains period 2020-03-01 00:00:00 to 2021-11-27 00:00:00.

# %%
# combine the second to fourth groups into a single one to  
# align with the county age distribution groups
age_5_17 = data[
    data['age_group'].isin(
        ['end_of_week', '5 - 11 Years', '12 - 15 Years', '16 - 17 Years']
    )
].groupby('end_of_week').aggregate('sum', numeric_only=True).reset_index()
age_5_17['age_group'] = '5 - 17 Years'

# %%
# drop the combined groups 
data = data[~data['age_group'].isin(['5 - 11 Years', '12 - 15 Years', '16 - 17 Years'])]

data = pd.concat([data, age_5_17]).reset_index(drop=True)

# %% [markdown]
# ### Plot

# %%
from Class.PlotConfig import *

# %%
fig, ax = plt.subplots(figsize=(13, 8))
colors = ['gray', '#fde725', '#7ad151', '#22a884', '#2a788e', '#414487', '#440154', 'black']
labels = ['0-4', '5-17', '18-29', '30-39', '40-49', '50-64', '65-74', '75+']

for index, (age_group, age_data) in enumerate(data.groupby('age_group')):
    ax.plot(
        age_data['end_of_week'], age_data['cases'], 
        color=colors[index], label=labels[index],
        linewidth=3.5 
        # marker=markers[index], markersize=8
    )

label_text = [] 
for loc in ax.get_yticks():
    if loc == 0:
        label_text.append('0')
    else:
        label_text.append(f'{loc/1e3:0.5g}K') 

ax.set_yticks(ax.get_yticks())
ax.set_yticklabels(label_text)
ax.set_ylim(0)

x_first_tick = data['end_of_week'].min()
x_last_tick = data['end_of_week'].max()
x_major_ticks = 5
ax.set_xticks(
    [x_first_tick + (x_last_tick - x_first_tick) * i / (x_major_ticks - 1) for i in range(x_major_ticks)]
)

plt.ylabel(f'Weekly COVID-19 Cases', labelpad=15)
# plt.title('Weekly COVID-19 Cases by Age Group', size=12)

plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left', title='Age Groups')

plt.savefig('weekly_ground_truth.jpg', bbox_inches='tight', dpi=200)
# plt.show()

# %% [markdown]
# ### Plot (old)

# %%
# # Prepare data for plotting
# x = data.end_of_week.unique()
# y1 = data[data.age_group == '0 - 4 Years'].cases
# y2 = data[data.age_group == '5 - 17 Years'].cases
# y3 = data[data.age_group == '18 - 29 Years'].cases
# y4 = data[data.age_group == '30 - 39 Years'].cases
# y5 = data[data.age_group == '40 - 49 Years'].cases
# y6 = data[data.age_group == '50 - 64 Years'].cases
# y7 = data[data.age_group == '65 - 74 Years'].cases
# y8 = data[data.age_group == '75+ Years'].cases

# %%
# mpl.rcParams['figure.dpi'] = 1000
# fig, ax = plt.subplots(nrows=1, ncols=1, facecolor='w', sharey=True, figsize=(6, 3))

# # Plot 
# plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y/%m/%d'))
# color = ['gray', '#fde725', '#7ad151', '#22a884', '#2a788e', '#414487', '#440154', 'black']
# label = ['0-4', '5-17', '18-29', '30-39', '40-49', '50-64', '65-74', '75+']
# plt.plot(x, y1, color = color[0], label=label[0])
# plt.plot(x, y2, color = color[1], label=label[1])
# plt.plot(x, y3, color = color[2], label=label[2])
# plt.plot(x, y4, color = color[3], label=label[3])
# plt.plot(x, y5, color = color[4], label=label[4])
# plt.plot(x, y6, color = color[5], label=label[5])
# plt.plot(x, y7, color = color[6], label=label[6])
# plt.plot(x, y8, color = color[7], label=label[7])

# # Format axis 
# ax.xaxis.set_major_locator(mdates.MonthLocator())
# ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
# ax.figure.autofmt_xdate(rotation=0, ha='center');
# ax.tick_params(labelsize=12, which='both')

# # Format labels
# ax.yaxis.set_major_formatter(OOMFormatter(3, "%5.0f"))
# ax.ticklabel_format(axis='y', style='sci')   
# ax.set_yticks([50e3, 100e3, 150e3, 200e3, 250e3, 300e3, 350e3], minor=True)
# ax.set_xlim('2020-03-07T00:00:00.000000000', '2021-11-27T00:00:00.000000000')
# ax.set_ylim(0, 400e3)

# for label in ax.xaxis.get_ticklabels()[::2]:
#     label.set_visible(False)

# # Add labels
# plt.ylabel('COVID-19 Cases', size=12)
# plt.xlabel('Date', size=12)
# plt.title('Weekly COVID-19 Cases by Age Group', size=12)
# plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left', title='Age Group')
# plt.savefig('fig2.png', bbox_inches='tight')
# plt.show()

# %% [markdown]
# ### Aggregate

# %%
# Find sum of all cases for each age group during time period
data = data.groupby(by=["age_group"]).sum('numeric_only').sort_index()

data
# Out:
#                   cases
# age_group
# 0 - 4 Years     1249223
# 18 - 29 Years  10018923
# 30 - 39 Years   7760789
# 40 - 49 Years   6767348
# 5 - 17 Years    6184296
# 50 - 64 Years   8820765
# 65 - 74 Years   3289094
# 75+ Years       2505606

# %%
# Out:
#                   cases
# age_group
# 0 - 4 Years     1249223
# 18 - 29 Years  10018923
# 30 - 39 Years   7760789
# 40 - 49 Years   6767348
# 5 - 17 Years    6184296
# 50 - 64 Years   8820765
# 65 - 74 Years   3289094
# 75+ Years       2505606

# %% [markdown]
# ## Population by Age
# ## These data are estimates for April 1, 2020
# https://www.census.gov/data/tables/time-series/demo/popest/2020s-national-detail.html

# %%
# Import data from csv
pop = pd.read_csv('Ground Truth/nc-est2021-agesex-res.csv', usecols=['SEX', 'AGE', 'ESTIMATESBASE2020'])
pop = pop[pop.SEX == 0]
pop = pop.rename(columns={'ESTIMATESBASE2020': 'population', 'AGE': 'age'})
pop = pop.drop(columns=['SEX'])

# Create age groups
age_04 = pop.iloc[0:5].population.values.sum()
age_517 = pop.iloc[5:18].population.values.sum()
age_1829 = pop.iloc[18:30].population.values.sum()
age_3039 = pop.iloc[30:40].population.values.sum()
age_4049 = pop.iloc[40:50].population.values.sum()
age_5064 = pop.iloc[50:65].population.values.sum()
age_6574 = pop.iloc[65:75].population.values.sum()
age_75plus = pop.iloc[75:101].population.values.sum()
pops = [age_04, age_517, age_1829, age_3039, age_4049, age_5064, age_6574, age_75plus]

# Using DataFrame.insert() to add a column
data.insert(1, "Population", pops, True)

# Final data frame
data = data.reindex(index = ['0 - 4 Years','5 - 17 Years','18 - 29 Years', '30 - 39 Years', '40 - 49 Years', \
                             '50 - 64 Years', '65 - 74 Years', '75+ Years'])

data.index.name = 'Age Group'
data = data.rename({'cases': 'Cases'}, axis=1)

# %%
data
# Out:
#                   Cases  Population
# Age Group
# 0 - 4 Years     1249223    19392551
# 5 - 17 Years    6184296    41003731
# 18 - 29 Years  10018923    54992661
# 30 - 39 Years   7760789    53013409
# 40 - 49 Years   6767348    45034182
# 50 - 64 Years   8820765    63876118
# 65 - 74 Years   3289094    32346340
# 75+ Years       2505606    21790289

# %% [markdown]
# # Ground Truth Ranking

# %%
# Calculate percentage of age infected 
percent_group = (data.Cases / data.Population).values * 100
data.insert(2, "Infection Rate (%)", np.round(percent_group, 2), True)

# %%
data.reset_index().style\
    .background_gradient('Blues', subset=['Infection Rate (%)'])\
    .format({'Cases': '{:,d}', 'Population': '{:,d}', 'Infection Rate (%)': '{:.1f}', 'Morris': '{:.0f}'})\
    .set_table_styles([dict(selector='th', props=[('text-align', 'center')])])\
    .set_properties(**{'text-align': 'center'})\
    .hide(axis='index')
# Out:
# <style type="text/css">
# #T_8bbc9 th {
#   text-align: center;
# }
# #T_8bbc9_row0_col0, #T_8bbc9_row0_col1, #T_8bbc9_row0_col2, #T_8bbc9_row1_col0, #T_8bbc9_row1_col1, #T_8bbc9_row1_col2, #T_8bbc9_row2_col0, #T_8bbc9_row2_col1, #T_8bbc9_row2_col2, #T_8bbc9_row3_col0, #T_8bbc9_row3_col1, #T_8bbc9_row3_col2, #T_8bbc9_row4_col0, #T_8bbc9_row4_col1, #T_8bbc9_row4_col2, #T_8bbc9_row5_col0, #T_8bbc9_row5_col1, #T_8bbc9_row5_col2, #T_8bbc9_row6_col0, #T_8bbc9_row6_col1, #T_8bbc9_row6_col2, #T_8bbc9_row7_col0, #T_8bbc9_row7_col1, #T_8bbc9_row7_col2 {
#   text-align: center;
# }
# #T_8bbc9_row0_col3 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-align: center;
# }
# #T_8bbc9_row1_col3 {
#   background-color: #2575b7;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_8bbc9_row2_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_8bbc9_row3_col3 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_8bbc9_row4_col3 {
#   background-color: #2676b8;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_8bbc9_row5_col3 {
#   background-color: #4191c6;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_8bbc9_row6_col3 {
#   background-color: #b0d2e7;
#   color: #000000;
#   text-align: center;
# }
# #T_8bbc9_row7_col3 {
#   background-color: #89bedc;
#   color: #000000;
#   text-align: center;
# }
# </style>
# <table id="T_8bbc9">
#   <thead>
#     <tr>
#       <th id="T_8bbc9_level0_col0" class="col_heading level0 col0" >Age Group</th>
#       <th id="T_8bbc9_level0_col1" class="col_heading level0 col1" >Cases</th>
#       <th id="T_8bbc9_level0_col2" class="col_heading level0 col2" >Population</th>
#       <th id="T_8bbc9_level0_col3" class="col_heading level0 col3" >Infection Rate (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8bbc9_row0_col0" class="data row0 col0" >0 - 4 Years</td>
#       <td id="T_8bbc9_row0_col1" class="data row0 col1" >1,249,223</td>
#       <td id="T_8bbc9_row0_col2" class="data row0 col2" >19,392,551</td>
#       <td id="T_8bbc9_row0_col3" class="data row0 col3" >6.4</td>
#     </tr>
#     <tr>
#       <td id="T_8bbc9_row1_col0" class="data row1 col0" >5 - 17 Years</td>
#       <td id="T_8bbc9_row1_col1" class="data row1 col1" >6,184,296</td>
#       <td id="T_8bbc9_row1_col2" class="data row1 col2" >41,003,731</td>
#       <td id="T_8bbc9_row1_col3" class="data row1 col3" >15.1</td>
#     </tr>
#     <tr>
#       <td id="T_8bbc9_row2_col0" class="data row2 col0" >18 - 29 Years</td>
#       <td id="T_8bbc9_row2_col1" class="data row2 col1" >10,018,923</td>
#       <td id="T_8bbc9_row2_col2" class="data row2 col2" >54,992,661</td>
#       <td id="T_8bbc9_row2_col3" class="data row2 col3" >18.2</td>
#     </tr>
#     <tr>
#       <td id="T_8bbc9_row3_col0" class="data row3 col0" >30 - 39 Years</td>
#       <td id="T_8bbc9_row3_col1" class="data row3 col1" >7,760,789</td>
#       <td id="T_8bbc9_row3_col2" class="data row3 col2" >53,013,409</td>
#       <td id="T_8bbc9_row3_col3" class="data row3 col3" >14.6</td>
#     </tr>
#     <tr>
#       <td id="T_8bbc9_row4_col0" class="data row4 col0" >40 - 49 Years</td>
#       <td id="T_8bbc9_row4_col1" class="data row4 col1" >6,767,348</td>
#       <td id="T_8bbc9_row4_col2" class="data row4 col2" >45,034,182</td>
#       <td id="T_8bbc9_row4_col3" class="data row4 col3" >15.0</td>
#     </tr>
#     <tr>
#       <td id="T_8bbc9_row5_col0" class="data row5 col0" >50 - 64 Years</td>
#       <td id="T_8bbc9_row5_col1" class="data row5 col1" >8,820,765</td>
#       <td id="T_8bbc9_row5_col2" class="data row5 col2" >63,876,118</td>
#       <td id="T_8bbc9_row5_col3" class="data row5 col3" >13.8</td>
#     </tr>
#     <tr>
#       <td id="T_8bbc9_row6_col0" class="data row6 col0" >65 - 74 Years</td>
#       <td id="T_8bbc9_row6_col1" class="data row6 col1" >3,289,094</td>
#       <td id="T_8bbc9_row6_col2" class="data row6 col2" >32,346,340</td>
#       <td id="T_8bbc9_row6_col3" class="data row6 col3" >10.2</td>
#     </tr>
#     <tr>
#       <td id="T_8bbc9_row7_col0" class="data row7 col0" >75+ Years</td>
#       <td id="T_8bbc9_row7_col1" class="data row7 col1" >2,505,606</td>
#       <td id="T_8bbc9_row7_col2" class="data row7 col2" >21,790,289</td>
#       <td id="T_8bbc9_row7_col3" class="data row7 col3" >11.5</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Add Morris ranking
morris = result['Morris']
data.insert(3, 'Morris', morris, True)

# %%
data.reset_index().style\
    .background_gradient('Blues', subset=['Infection Rate (%)', 'Morris'])\
    .format({'Cases': '{:,d}', 'Population': '{:,d}', 'Infection Rate (%)': '{:.1f}', 'Morris': '{:.0f}'})\
    .set_table_styles([dict(selector='th', props=[('text-align', 'center')])])\
    .set_properties(**{'text-align': 'center'})\
    .hide(axis='index')
# Out:
# <style type="text/css">
# #T_1cb9b th {
#   text-align: center;
# }
# #T_1cb9b_row0_col0, #T_1cb9b_row0_col1, #T_1cb9b_row0_col2, #T_1cb9b_row1_col0, #T_1cb9b_row1_col1, #T_1cb9b_row1_col2, #T_1cb9b_row2_col0, #T_1cb9b_row2_col1, #T_1cb9b_row2_col2, #T_1cb9b_row3_col0, #T_1cb9b_row3_col1, #T_1cb9b_row3_col2, #T_1cb9b_row4_col0, #T_1cb9b_row4_col1, #T_1cb9b_row4_col2, #T_1cb9b_row5_col0, #T_1cb9b_row5_col1, #T_1cb9b_row5_col2, #T_1cb9b_row6_col0, #T_1cb9b_row6_col1, #T_1cb9b_row6_col2, #T_1cb9b_row7_col0, #T_1cb9b_row7_col1, #T_1cb9b_row7_col2 {
#   text-align: center;
# }
# #T_1cb9b_row0_col3, #T_1cb9b_row0_col4 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-align: center;
# }
# #T_1cb9b_row1_col3 {
#   background-color: #2575b7;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1cb9b_row1_col4 {
#   background-color: #dbe9f6;
#   color: #000000;
#   text-align: center;
# }
# #T_1cb9b_row2_col3, #T_1cb9b_row2_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1cb9b_row3_col3 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1cb9b_row3_col4, #T_1cb9b_row7_col4 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1cb9b_row4_col3 {
#   background-color: #2676b8;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1cb9b_row4_col4 {
#   background-color: #0b559f;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1cb9b_row5_col3 {
#   background-color: #4191c6;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_1cb9b_row5_col4, #T_1cb9b_row7_col3 {
#   background-color: #89bedc;
#   color: #000000;
#   text-align: center;
# }
# #T_1cb9b_row6_col3 {
#   background-color: #b0d2e7;
#   color: #000000;
#   text-align: center;
# }
# #T_1cb9b_row6_col4 {
#   background-color: #bad6eb;
#   color: #000000;
#   text-align: center;
# }
# </style>
# <table id="T_1cb9b">
#   <thead>
#     <tr>
#       <th id="T_1cb9b_level0_col0" class="col_heading level0 col0" >Age Group</th>
#       <th id="T_1cb9b_level0_col1" class="col_heading level0 col1" >Cases</th>
#       <th id="T_1cb9b_level0_col2" class="col_heading level0 col2" >Population</th>
#       <th id="T_1cb9b_level0_col3" class="col_heading level0 col3" >Infection Rate (%)</th>
#       <th id="T_1cb9b_level0_col4" class="col_heading level0 col4" >Morris</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1cb9b_row0_col0" class="data row0 col0" >0 - 4 Years</td>
#       <td id="T_1cb9b_row0_col1" class="data row0 col1" >1,249,223</td>
#       <td id="T_1cb9b_row0_col2" class="data row0 col2" >19,392,551</td>
#       <td id="T_1cb9b_row0_col3" class="data row0 col3" >6.4</td>
#       <td id="T_1cb9b_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
#       <td id="T_1cb9b_row1_col0" class="data row1 col0" >5 - 17 Years</td>
#       <td id="T_1cb9b_row1_col1" class="data row1 col1" >6,184,296</td>
#       <td id="T_1cb9b_row1_col2" class="data row1 col2" >41,003,731</td>
#       <td id="T_1cb9b_row1_col3" class="data row1 col3" >15.1</td>
#       <td id="T_1cb9b_row1_col4" class="data row1 col4" >2</td>
#     </tr>
#     <tr>
#       <td id="T_1cb9b_row2_col0" class="data row2 col0" >18 - 29 Years</td>
#       <td id="T_1cb9b_row2_col1" class="data row2 col1" >10,018,923</td>
#       <td id="T_1cb9b_row2_col2" class="data row2 col2" >54,992,661</td>
#       <td id="T_1cb9b_row2_col3" class="data row2 col3" >18.2</td>
#       <td id="T_1cb9b_row2_col4" class="data row2 col4" >8</td>
#     </tr>
#     <tr>
#       <td id="T_1cb9b_row3_col0" class="data row3 col0" >30 - 39 Years</td>
#       <td id="T_1cb9b_row3_col1" class="data row3 col1" >7,760,789</td>
#       <td id="T_1cb9b_row3_col2" class="data row3 col2" >53,013,409</td>
#       <td id="T_1cb9b_row3_col3" class="data row3 col3" >14.6</td>
#       <td id="T_1cb9b_row3_col4" class="data row3 col4" >6</td>
#     </tr>
#     <tr>
#       <td id="T_1cb9b_row4_col0" class="data row4 col0" >40 - 49 Years</td>
#       <td id="T_1cb9b_row4_col1" class="data row4 col1" >6,767,348</td>
#       <td id="T_1cb9b_row4_col2" class="data row4 col2" >45,034,182</td>
#       <td id="T_1cb9b_row4_col3" class="data row4 col3" >15.0</td>
#       <td id="T_1cb9b_row4_col4" class="data row4 col4" >7</td>
#     </tr>
#     <tr>
#       <td id="T_1cb9b_row5_col0" class="data row5 col0" >50 - 64 Years</td>
#       <td id="T_1cb9b_row5_col1" class="data row5 col1" >8,820,765</td>
#       <td id="T_1cb9b_row5_col2" class="data row5 col2" >63,876,118</td>
#       <td id="T_1cb9b_row5_col3" class="data row5 col3" >13.8</td>
#       <td id="T_1cb9b_row5_col4" class="data row5 col4" >4</td>
#     </tr>
#     <tr>
#       <td id="T_1cb9b_row6_col0" class="data row6 col0" >65 - 74 Years</td>
#       <td id="T_1cb9b_row6_col1" class="data row6 col1" >3,289,094</td>
#       <td id="T_1cb9b_row6_col2" class="data row6 col2" >32,346,340</td>
#       <td id="T_1cb9b_row6_col3" class="data row6 col3" >10.2</td>
#       <td id="T_1cb9b_row6_col4" class="data row6 col4" >3</td>
#     </tr>
#     <tr>
#       <td id="T_1cb9b_row7_col0" class="data row7 col0" >75+ Years</td>
#       <td id="T_1cb9b_row7_col1" class="data row7 col1" >2,505,606</td>
#       <td id="T_1cb9b_row7_col2" class="data row7 col2" >21,790,289</td>
#       <td id="T_1cb9b_row7_col3" class="data row7 col3" >11.5</td>
#       <td id="T_1cb9b_row7_col4" class="data row7 col4" >6</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Add population ranking 
data['Population'] = data['Infection Rate (%)'].rank(ascending=True)
data = data.drop(columns=['Cases', 'Infection Rate (%)'])
ranking[['mean_rows']].style.background_gradient('Blues', subset=['mean_rows'])\
       .format({'mean_rows': '{:.2f}'})
data

# Add difference in ranking 
change = abs(data['Population'] - data['Morris'])
data.insert(2, 'Difference', change, True)

# Change name to true
data = data.rename(columns={'Population': 'True'})

# %%
data[['True', 'Morris', 'Difference']].reset_index().style\
    .background_gradient('Blues', subset=['Morris', 'True'])\
    .background_gradient('Reds', subset=['Difference'])\
    .set_table_styles([dict(selector='th', props=[('text-align', 'center')])])\
    .format({'Morris': '{:.0f}', 'True': '{:.0f}', 'Difference': '{:.0f}'})\
    .set_properties( **{'text-align': 'center'})\
    .hide(axis='index')
# Out:
# <style type="text/css">
# #T_88f00 th {
#   text-align: center;
# }
# #T_88f00_row0_col0, #T_88f00_row1_col0, #T_88f00_row2_col0, #T_88f00_row3_col0, #T_88f00_row4_col0, #T_88f00_row5_col0, #T_88f00_row6_col0, #T_88f00_row7_col0 {
#   text-align: center;
# }
# #T_88f00_row0_col1, #T_88f00_row0_col2 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-align: center;
# }
# #T_88f00_row0_col3, #T_88f00_row2_col3, #T_88f00_row5_col3 {
#   background-color: #fff5f0;
#   color: #000000;
#   text-align: center;
# }
# #T_88f00_row1_col1, #T_88f00_row4_col2 {
#   background-color: #0b559f;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_88f00_row1_col2, #T_88f00_row6_col1 {
#   background-color: #dbe9f6;
#   color: #000000;
#   text-align: center;
# }
# #T_88f00_row1_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_88f00_row2_col1, #T_88f00_row2_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_88f00_row3_col1 {
#   background-color: #539ecd;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_88f00_row3_col2, #T_88f00_row7_col2 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_88f00_row3_col3 {
#   background-color: #fee5d8;
#   color: #000000;
#   text-align: center;
# }
# #T_88f00_row4_col1 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_88f00_row4_col3, #T_88f00_row6_col3 {
#   background-color: #fdcab5;
#   color: #000000;
#   text-align: center;
# }
# #T_88f00_row5_col1, #T_88f00_row5_col2 {
#   background-color: #89bedc;
#   color: #000000;
#   text-align: center;
# }
# #T_88f00_row6_col2, #T_88f00_row7_col1 {
#   background-color: #bad6eb;
#   color: #000000;
#   text-align: center;
# }
# #T_88f00_row7_col3 {
#   background-color: #fb694a;
#   color: #f1f1f1;
#   text-align: center;
# }
# </style>
# <table id="T_88f00">
#   <thead>
#     <tr>
#       <th id="T_88f00_level0_col0" class="col_heading level0 col0" >Age Group</th>
#       <th id="T_88f00_level0_col1" class="col_heading level0 col1" >True</th>
#       <th id="T_88f00_level0_col2" class="col_heading level0 col2" >Morris</th>
#       <th id="T_88f00_level0_col3" class="col_heading level0 col3" >Difference</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_88f00_row0_col0" class="data row0 col0" >0 - 4 Years</td>
#       <td id="T_88f00_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_88f00_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_88f00_row0_col3" class="data row0 col3" >0</td>
#     </tr>
#     <tr>
#       <td id="T_88f00_row1_col0" class="data row1 col0" >5 - 17 Years</td>
#       <td id="T_88f00_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_88f00_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_88f00_row1_col3" class="data row1 col3" >5</td>
#     </tr>
#     <tr>
#       <td id="T_88f00_row2_col0" class="data row2 col0" >18 - 29 Years</td>
#       <td id="T_88f00_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_88f00_row2_col2" class="data row2 col2" >8</td>
#       <td id="T_88f00_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <td id="T_88f00_row3_col0" class="data row3 col0" >30 - 39 Years</td>
#       <td id="T_88f00_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_88f00_row3_col2" class="data row3 col2" >6</td>
#       <td id="T_88f00_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <td id="T_88f00_row4_col0" class="data row4 col0" >40 - 49 Years</td>
#       <td id="T_88f00_row4_col1" class="data row4 col1" >6</td>
#       <td id="T_88f00_row4_col2" class="data row4 col2" >7</td>
#       <td id="T_88f00_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#     <tr>
#       <td id="T_88f00_row5_col0" class="data row5 col0" >50 - 64 Years</td>
#       <td id="T_88f00_row5_col1" class="data row5 col1" >4</td>
#       <td id="T_88f00_row5_col2" class="data row5 col2" >4</td>
#       <td id="T_88f00_row5_col3" class="data row5 col3" >0</td>
#     </tr>
#     <tr>
#       <td id="T_88f00_row6_col0" class="data row6 col0" >65 - 74 Years</td>
#       <td id="T_88f00_row6_col1" class="data row6 col1" >2</td>
#       <td id="T_88f00_row6_col2" class="data row6 col2" >3</td>
#       <td id="T_88f00_row6_col3" class="data row6 col3" >1</td>
#     </tr>
#     <tr>
#       <td id="T_88f00_row7_col0" class="data row7 col0" >75+ Years</td>
#       <td id="T_88f00_row7_col1" class="data row7 col1" >3</td>
#       <td id="T_88f00_row7_col2" class="data row7 col2" >6</td>
#       <td id="T_88f00_row7_col3" class="data row7 col3" >2</td>
#     </tr>
#   </tbody>
# </table>
